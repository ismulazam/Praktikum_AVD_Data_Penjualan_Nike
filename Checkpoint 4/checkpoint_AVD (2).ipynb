# %% [markdown]
# # **RECAP DATA PENJUALAN DAN PENDAPATAN BRAND NIKE**

# %% [markdown]
# # **IMPORT LIBRARY**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # **Business Understanding**

# %% [markdown]
# ## **Business Objective**

# %% [markdown]
# **Tujuan** dari analisis ini adalah membantu Nike menjaga keuntungan tetap stabil meskipun persaingan tinggi dan strategi diskon sering digunakan. Perusahaan ingin mengetahui produk mana yang paling menguntungkan, wilayah mana yang memberikan kontribusi terbesar, serta saluran penjualan (Online atau Retail) mana yang lebih efektif. Selain itu, Nike ingin memastikan bahwa strategi diskon yang diberikan benar-benar meningkatkan penjualan tanpa mengurangi laba secara signifikan.
#
# **masalah yang ada:** Nike adalah salah satu perusahaan sepatu terbesar di dunia dengan penjualan yang sangat tinggi di berbagai negara. Namun, meskipun penjualannya besar, perusahaan tetap menghadapi masalah seperti keuntungan yang tidak selalu stabil, adanya produk yang kurang menguntungkan, serta pemberian diskon yang belum tentu meningkatkan laba. Jika hal ini tidak dianalisis dengan baik, perusahaan bisa mengalami penurunan keuntungan meskipun penjualan terlihat ramai. Oleh karena itu, data penjualan perlu dianalisis untuk mengetahui produk, wilayah, dan cara penjualan mana yang paling menguntungkan agar Nike tetap konsisten dan terus mendapatkan keuntungan.
#
# Dataset ini berisi data penjualan produk retail yang mencakup informasi seperti produk, wilayah, saluran penjualan (Online dan Retail), jumlah unit terjual, diskon, revenue, dan profit. Data ini digunakan untuk melihat kinerja penjualan serta menganalisis keuntungan perusahaan berdasarkan berbagai faktor yang memengaruhinya.

# %% [markdown]
# ## **Assess Situation**

# %% [markdown]
# Saat ini, Nike memiliki banyak data penjualan yang mencatat produk yang terjual, wilayah penjualan, cara penjualan (Online atau Retail), jumlah barang yang terjual, diskon yang diberikan, serta keuntungan yang didapat. Namun dari data tersebut terlihat bahwa keuntungan tidak selalu stabil. Ada beberapa penjualan yang keuntungannya kecil bahkan ada yang rugi. Selain itu, belum diketahui dengan jelas apakah diskon yang diberikan benar-benar membantu meningkatkan keuntungan atau justru mengurangi laba. Jika kondisi ini dibiarkan saja, perusahaan bisa terus mengambil keputusan yang kurang tepat. Namun, karena data penjualan sudah tersedia, perusahaan bisa menganalisis dan memiliki peluang besar untuk memanfaatkannya agar strategi penjualan menjadi lebih efektif dan menguntungkan.

# %% [markdown]
# ## **Analitic Goals & Project Plan**

# %% [markdown]
# Analitic Goals:
# 1. Mengetahui produk mana yang paling banyak menghasilkan keuntungan.
# 2. Melihat wilayah mana yang penjualannya paling tinggi dan paling rendah.
# 3. Membandingkan mana yang lebih menguntungkan, penjualan Online atau Retail.
# 4. Mengetahui apakah pemberian diskon benar-benar membantu meningkatkan keuntungan atau justru membuat rugi.
# 5. Mencari tahu penyebab adanya penjualan yang keuntungannya sangat kecil atau bahkan negatif.
#
# Project Plan:
# 1. Melihat dan memahami isi dataset untuk mengetahui data apa saja yang tersedia.
# 2. Membersihkan data jika ada nilai kosong, salah input, atau data yang tidak sesuai.
# 3. Menghitung dan membandingkan total penjualan dan keuntungan berdasarkan produk, wilayah, dan cara penjualan.
# 4. Membuat grafik atau visualisasi agar hasil analisis lebih mudah dipahami.
# 5. Menarik kesimpulan dan memberikan saran agar Nike bisa meningkatkan keuntungan dan menjaga bisnis tetap stabil.

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ## **Memuat Dataset**

# %% [markdown]
# Dataset ini berasal dari data penjualan Nike, yang bertujuan untuk mengevaluasi & meningkatkan penjualan dalam skala Global

# %%
file = "/content/Nike_Sales_Uncleaned (1).csv"
df = pd.read_csv(file)

df
# Out:
#       Order_ID Gender_Category Product_Line      Product_Name Size  \
# 0         2000            Kids     Training       SuperRep Go    M
# 1         2001           Women       Soccer     Tiempo Legend    M
# 2         2002           Women       Soccer       Premier III    M
# 3         2003            Kids    Lifestyle        Blazer Mid    L
# 4         2004            Kids      Running    React Infinity   XL
# ...        ...             ...          ...               ...  ...
# 2495      4495            Kids   Basketball     Kyrie Flytrap   XL
# 2496      4496             Men   Basketball     Kyrie Flytrap    L
# 2497      4497             Men       Soccer     Tiempo Legend    7
# 2498      4498           Women     Training  ZoomX Invincible  NaN
# 2499      4499           Women      Running          Air Zoom    M
#
#       Units_Sold      MRP  Discount_Applied  Revenue  Order_Date  \
# 0            NaN      NaN              0.47      0.0  2024-03-09
# ...

# %% [markdown]
# ## **Deskripsi Data**

# %% [markdown]
# ### **Informasi Dasar**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          2500 non-null   int64
#  1   Gender_Category   2500 non-null   object
#  2   Product_Line      2500 non-null   object
#  3   Product_Name      2500 non-null   object
#  4   Size              1990 non-null   object
#  5   Units_Sold        1265 non-null   float64
#  6   MRP               1246 non-null   float64
#  7   Discount_Applied  832 non-null    float64
#  8   Revenue           2500 non-null   float64
#  9   Order_Date        1884 non-null   object
#  10  Sales_Channel     2500 non-null   object
#  11  Region            2500 non-null   object
#  12  Profit            2500 non-null   float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 254.0+ KB

# %% [markdown]
# Berdasarkan data di atas, dapat diketahui bahwa dataset ini memiliki 2500 Baris dan 13 Kolom

# %% [markdown]
# ### **Informasi Lanjutan**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          2500 non-null   int64
#  1   Gender_Category   2500 non-null   object
#  2   Product_Line      2500 non-null   object
#  3   Product_Name      2500 non-null   object
#  4   Size              1990 non-null   object
#  5   Units_Sold        1265 non-null   float64
#  6   MRP               1246 non-null   float64
#  7   Discount_Applied  832 non-null    float64
#  8   Revenue           2500 non-null   float64
#  9   Order_Date        1884 non-null   object
#  10  Sales_Channel     2500 non-null   object
#  11  Region            2500 non-null   object
#  12  Profit            2500 non-null   float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 254.0+ KB

# %% [markdown]
# 1.   Order_ID
# - Jumlah baris: 2500
# - Tipe data: int64
# - Deskripsi: ID unik untuk setiap pesanan.
# 2.   Gender_Category
# - Jumlah baris: 2500
# - Tipe data: object
# - Deskripsi: Kategori gender pelanggan.
# 3.   Product_Line
# - Jumlah baris: 2500
# - Tipe data: object
# - Deskripsi: Lini atau jenis produk yang dijual.
# 4.   Product_Name
# - Jumlah baris: 2500
# - Tipe data: object
# - Deskripsi: Nama produk yang dibeli.
# 5.   Size
# - Jumlah baris: 1990
# - Tipe data: object
# - Deskripsi: Ukuran produk yang dibeli (terdapat 510 data kosong, tapi tidak perlu ditangani karena tidak berhubungan dengan yang akan dianalisis).
# 6.   Units_Sold
# - Jumlah baris: 1265
# - Tipe data: float64
# - Deskripsi: Jumlah unit produk yang terjual (terdapat 1235 data kosong).
# 7.   MRP
# - Jumlah baris: 1246
# - Tipe data: float64
# - Deskripsi: Harga dasar produk sebelum diskon (terdapat 1254 data kosong).
# 8.   Discount_Applied
# - Jumlah baris: 832
# - Tipe data: float64
# - Deskripsi: Besaran diskon yang diterapkan pada produk (terdapat 1668 data kosong).
# 9.   Revenue
# - Jumlah baris: 2500
# - Tipe data: float64
# - Deskripsi: Total pendapatan dari penjualan.
# 10.   Order_Date
# - Jumlah baris: 1884
# - Tipe data: object
# - Deskripsi: Tanggal pemesanan dilakukan (terdapat 616 data kosong).
# 11.   Sales_Channel
# - Jumlah baris: 2500
# - Tipe data: object
# - Deskripsi: Kategori gender pelanggan.
# 12.   Region
# - Jumlah baris: 2500
# - Tipe data: object
# - Deskripsi: Wilayah atau area penjualan.
# 13.   Profit
# - Jumlah baris: 2500
# - Tipe data: float64
# - Deskripsi: Keuntungan yang diperoleh dari penjualan.

# %% [markdown]
# ### **Informasi Statistik Deskriptif**

# %%
df.value_counts() // df["Size"].value_counts()
# Out:
# Order_ID  Gender_Category  Product_Line  Product_Name        Size  Units_Sold  MRP      Discount_Applied  Revenue    Order_Date  Sales_Channel  Region     Profit
# 2003      Women            Lifestyle     Waffle One          XL     2.0        8516.45  0.22               13285.66  2023-09-30  Online         Kolkata     1764.52    0
#                            Training      ZoomX Invincible    XL     4.0        7850.87  1.02              -628.07    2025/04/01  Online         Kolkata     992.14     0
# 2019      Kids             Running       Air Zoom            6      0.0        3424.06  0.32               0.00      2025/01/17  Online         Hyderabad   1915.24    0
#           Men              Lifestyle     Air Force 1         L     -1.0        2452.52  0.12              -2158.22   26-07-2024  Retail         Hyd        -1199.45    0
# ...

# %%
df.describe(include='all')
# Out:
#            Order_ID Gender_Category Product_Line Product_Name  Size  \
# count   2500.000000            2500         2500         2500  1990
# unique          NaN               3            5           20    10
# top             NaN            Kids     Training  SuperRep Go     L
# freq            NaN             841          546          148   513
# mean    3194.352400             NaN          NaN          NaN   NaN
# std      749.972638             NaN          NaN          NaN   NaN
# min     2000.000000             NaN          NaN          NaN   NaN
# 25%     2534.750000             NaN          NaN          NaN   NaN
# 50%     3192.500000             NaN          NaN          NaN   NaN
# 75%     3841.250000             NaN          NaN          NaN   NaN
# max     4499.000000             NaN          NaN          NaN   NaN
#
#          Units_Sold          MRP  Discount_Applied       Revenue  Order_Date  \
# ...

# %% [markdown]
# 1.   Count Berdasarkan data, total baris transaksi adalah 2500. Maka dapat disimpulkan:
# *   Size hilang 510 data (2500 - 1990)
# *   Units_Sold hilang 1235 data (2500 - 1265)
# *   MRP hilang 1254 data (2500 - 1246)
# *   Discount_Applied hilang 1668 data (2500 - 832)
# *   Order_Date hilang 616 data (2500 - 1884)
#
#
# Kolom lainnya seperti Order_ID, Gender_Category, Product_Line, Product_Name, Revenue, Sales_Channel, Region, dan Profit sudah lengkap (2500 data).
#
# Kesimpulan:
# Dataset memiliki missing value yang cukup besar pada variabel operasional seperti Units_Sold, MRP, dan Discount_Applied. Hal ini dapat memengaruhi analisis harga dan volume penjualan, sehingga diperlukan proses data cleaning sebelum analisis lanjutan.
#
#
#
# ---
#
#
# 2.  Mean vs Median (Distribusi Data)
#
# * Kolom Revenue
#   *  Mean = 274,87
#   * Median = 0,00
#
# Nilai rata-rata jauh lebih besar dibanding median, menunjukkan sebagian besar transaksi memiliki revenue kecil atau nol, namun terdapat beberapa transaksi dengan nilai sangat besar (outlier) yang menarik rata-rata naik.
#
# - Kolom Units_Sold
#   * Mean = 1,48
#   * Median = 2,00
#
# Median sedikit lebih besar dari mean. Ini menunjukkan distribusi relatif stabil, namun terdapat nilai ekstrem seperti -1 yang menurunkan rata-rata.
#
# - Kolom Profit
#   * Mean = 1376,01
#   * Median = 1371,39
#
# Nilai mean dan median sangat dekat, menunjukkan distribusi keuntungan relatif simetris dan tidak terlalu dipengaruhi oleh outlier.
#
# Kesimpulan:
#
# Revenue bersifat right-skewed (condong ke kanan) karena banyak nilai nol dan beberapa nilai sangat tinggi.
# Profit cenderung stabil karena mean dan median hampir sama.
# Units_Sold relatif normal, namun terdapat indikasi anomali pada nilai minimum.
#
#
# ---
#
# 3. Min dan Max (Validasi Logika)
#
# * Revenue
#   * Min = -7561,59
#   * Max = 37169,35
#
# * Units_Sold
#   * Min = -1
#   * Max = 4
#
# * Profit
#   * Min = -1199,45
#   * Max = 3999,21
#
# Kesimpulan:
# * Units_Sold memiliki nilai minimum -1, yang secara logika tidak valid (jumlah unit tidak mungkin negatif). Ini kemungkinan kesalahan input data.
# * Revenue memiliki nilai negatif (-7561), yang menunjukkan kemungkinan retur atau koreksi transaksi.
# * Profit memiliki nilai negatif (-1199), menunjukkan adanya transaksi yang merugi.
# * Rentang Revenue sangat lebar (hingga 37.169), menunjukkan variasi nilai transaksi yang signifikan.
#
# Validasi data sangat diperlukan sebelum analisis lebih lanjut.
#
#
#
# ---
#
# Standar Deviasi (Std) Variabilitas Data
# * Revenue
#   * Mean = 274,87
#   * Std = 2023,77
#
# Standar deviasi jauh lebih besar dari mean, menunjukkan variasi revenue antar transaksi sangat tinggi dan tidak stabil.
#
# * Profit
#   * Mean = 1376,01
#   * Std = 1478,67
#
# Nilai standar deviasi sedikit lebih besar dari mean, menunjukkan fluktuasi keuntungan yang cukup tinggi antar transaksi.
#
# * Units_Sold
#   * Mean = 1,48
#   * Std = 1,69
#
# Standar deviasi hampir sama dengan mean, menunjukkan variasi jumlah pembelian antar transaksi cukup besar dibanding rata-ratanya.
#
#
# ---
#
# Kesimpulan Akhir:
#
# Dataset menunjukkan:
# * Variasi transaksi sangat tinggi terutama pada Revenue.
# * Terdapat nilai negatif dan anomali yang perlu dibersihkan.
# * Profit relatif lebih stabil dibanding Revenue.
# * Data belum siap untuk modeling tanpa proses data cleaning dan validasi lebih lanjut.

# %% [markdown]
# ## **Verifikasi Kualitas Data**

# %% [markdown]
# ### **Data Type Check**

# %%
df.dtypes
# Out:
# Order_ID              int64
# Gender_Category      object
# Product_Line         object
# Product_Name         object
# Size                 object
# Units_Sold          float64
# MRP                 float64
# Discount_Applied    float64
# Revenue             float64
# Order_Date           object
# Sales_Channel        object
# Region               object
# Profit              float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          2500 non-null   int64
#  1   Gender_Category   2500 non-null   object
#  2   Product_Line      2500 non-null   object
#  3   Product_Name      2500 non-null   object
#  4   Size              1990 non-null   object
#  5   Units_Sold        1265 non-null   float64
#  6   MRP               1246 non-null   float64
#  7   Discount_Applied  832 non-null    float64
#  8   Revenue           2500 non-null   float64
#  9   Order_Date        1884 non-null   object
#  10  Sales_Channel     2500 non-null   object
#  11  Region            2500 non-null   object
#  12  Profit            2500 non-null   float64
# dtypes: float64(5), int64(1), object(7)
# memory usage: 254.0+ KB

# %% [markdown]
# Kita akan mengecek tipe data dari setiap kolom apakah sudah sesuai atau tidak. Agar insight serta visualisasi yang akan kita buat menjadi akurat.
#
# Temuan:
# Beberapa kolom numerik dan tanggal masih terbaca sebagai object, terutama pada:
# * Order_Date
# * MRP
# * Revenue
# * Discount_Applied
# * Profit
#
# Insight:
#
# Ketidaksesuaian tipe data menunjukkan bahwa dataset ini memang belum melalui proses validasi sistem yang baik. ini sering terjadi ketika data digabung dari berbagai sumber (retail POS, website, Excel manual).
#
# Kesimpulan:
#
# Perlu konversi dan perbaikan agar analisis lebih akurat dan optimal.

# %% [markdown]
# ### **Inconsistent Values**

# %%
df['Region'].unique()
df['Gender_Category'].unique()
df['Product_Line'].unique()
df['Sales_Channel'].unique()
# Out:
# array(['Online', 'Retail'], dtype=object)

# %%
df[df['Units_Sold'] < 0]
# Out:
#       Order_ID Gender_Category Product_Line   Product_Name Size  Units_Sold  \
# 8         2008           Women       Soccer    Premier III   11        -1.0
# 11        2011           Women     Training   Flex Trainer    L        -1.0
# 12        2018            Kids    Lifestyle     Blazer Mid  NaN        -1.0
# 20        2020            Kids       Soccer  Tiempo Legend    L        -1.0
# 21        2021             Men      Running        Free RN    L        -1.0
# ...        ...             ...          ...            ...  ...         ...
# 2410      4410             Men   Basketball  Kyrie Flytrap   XL        -1.0
# 2457      2019             Men    Lifestyle    Air Force 1    L        -1.0
# 2459      4459             Men     Training    SuperRep Go  NaN        -1.0
# 2460      4460           Women       Soccer  Tiempo Legend    M        -1.0
# 2496      4496             Men   Basketball  Kyrie Flytrap    L        -1.0
#
# ...

# %%
df[df['Discount_Applied'] > 1]
# Out:
#       Order_ID Gender_Category Product_Line   Product_Name Size  Units_Sold  \
# 18        2018             Men     Training       Metcon 7   XL         0.0
# 30        2030             Men       Soccer     Phantom GT   XL         NaN
# 32        2032           Women    Lifestyle     Blazer Mid   XL         1.0
# 37        2037            Kids      Running  Pegasus Turbo    7         3.0
# 46        2046            Kids      Running       Air Zoom   12         NaN
# ...        ...             ...          ...            ...  ...         ...
# 2420      4420           Women    Lifestyle     Blazer Mid    L         4.0
# 2443      4443             Men    Lifestyle       Dunk Low    9         3.0
# 2468      4468             Men       Soccer    Premier III   XL         3.0
# 2475      4475            Kids       Soccer  Tiempo Legend    M         NaN
# 2489      4489            Kids    Lifestyle     Blazer Mid    9         3.0
#
# ...

# %%
df[df['Revenue'] < 0]
# Out:
#       Order_ID Gender_Category Product_Line        Product_Name Size  \
# 21        2021             Men      Running             Free RN    L
# 37        2037            Kids      Running       Pegasus Turbo    7
# 234       2234             Men     Training        Flex Trainer  NaN
# 242       2046            Kids   Basketball           LeBron 20  NaN
# 264       2264             Men     Training    ZoomX Invincible  NaN
# 359       2359             Men    Lifestyle          Waffle One    L
# 381       2381            Kids    Lifestyle            Dunk Low    M
# 384       2384           Women     Training         SuperRep Go  NaN
# 416       2416            Kids       Soccer  Mercurial Superfly    9
# 434       2434            Kids     Training            Metcon 7    M
# 511       2511             Men      Running       Pegasus Turbo  NaN
# 572       2572             Men    Lifestyle          Waffle One   XL
# 630       2630            Kids      Running       Pegasus Turbo  NaN
# ...

# %%
df['Order_Date'].unique()
# Out:
# array(['2024-03-09', '2024-07-09', nan, ..., '2025-04-02', '12-02-2025',
#        '2025-05-14'], dtype=object)

# %%
df['Size'].unique()
# Out:
# array(['M', 'L', 'XL', '11', nan, '9', '6', '12', '7', '10', '8'],
#       dtype=object)

# %% [markdown]
# Temuan:
# * Typo pada Region (contoh: “Delhii”, “Banglore”)
# * Format berbeda pada Order_Date
# * Discount_Applied melebihi 100%
# * Potensi variasi penulisan pada Sales_Channel atau Gender_Category
#
# Insight:
# Typo pada nama kota bisa menyebabkan:
# * Fragmentasi data regional
# * Salah interpretasi performa kota
# * Dashboard menampilkan kota yang sebenarnya sama sebagai entitas berbeda
#
# Diskon >100% menunjukkan:
# * Kesalahan input manual
# * Atau bug sistem
#
# Dalam bisnis retail, diskon tidak mungkin melebihi 100% karena berarti perusahaan membayar pelanggan.
#
# Kesimpulan:
#
# Dataset ini meniru kondisi nyata di mana kontrol validasi input belum optimal.

# %% [markdown]
# ### **Missing Values**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                   Null Ratio in %
# Order_ID                     0.00
# Gender_Category              0.00
# Product_Line                 0.00
# Product_Name                 0.00
# Size                        20.40
# Units_Sold                  49.40
# MRP                         50.16
# Discount_Applied            66.72
# Revenue                      0.00
# Order_Date                  24.64
# Sales_Channel                0.00
# Region                       0.00
# Profit                       0.00

# %% [markdown]
# Pada tahap ini, kita akan melihat seberapa banyak data yang hilang pada seluruh kolom.
#
# Temuan:
# * Discount_Applied hilang 1668 data (sekitar 67%)
# * MRP hilang 1254 data (sekitar 50%)
# * Units_Sold hilang 1235 data (sekitar 49%)
# * Order_Date hilang 616 data (sekitar 24%)
# * Size hilang 510 data (sekitar 20%)
#
# Insight:
#
# Tingkat missing value pada variabel harga dan diskon sangat tinggi.
# Ini dapat mengganggu analisis profit margin, pricing strategy, dan volume penjualan.
#
# Kesimpulan:
#
# Dataset memerlukan strategi penanganan missing value:
# * Imputasi (mean/median/mode)
# * Penghapusan baris tertentu
#
# Tanpa pembersihan, hasil analisis bisa bias.

# %%
missing = pd.DataFrame({
    'Missing Count': df.isna().sum(),
    'Missing %': (df.isna().sum() / len(df)) * 100
})
missing
# Out:
#                   Missing Count  Missing %
# Order_ID                      0       0.00
# Gender_Category               0       0.00
# Product_Line                  0       0.00
# Product_Name                  0       0.00
# Size                        510      20.40
# Units_Sold                 1235      49.40
# MRP                        1254      50.16
# Discount_Applied           1668      66.72
# Revenue                       0       0.00
# Order_Date                  616      24.64
# Sales_Channel                 0       0.00
# Region                        0       0.00
# Profit                        0       0.00

# %% [markdown]
# ### **Duplicated Values**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated(subset='Order_ID')]
# Out:
#       Order_ID Gender_Category Product_Line    Product_Name Size  Units_Sold  \
# 18        2018             Men     Training        Metcon 7   XL         0.0
# 40        2002           Women   Basketball      Zoom Freak   XL         3.0
# 57        2048             Men    Lifestyle      Waffle One    M         3.0
# 82        2028             Men      Running         Free RN  NaN        -1.0
# 121       2000            Kids      Running  React Infinity    M        -1.0
# ...        ...             ...          ...             ...  ...         ...
# 2372      2029            Kids      Running         Free RN    M         NaN
# 2424      2007             Men       Soccer      Phantom GT    L         NaN
# 2448      2030           Women   Basketball      Air Jordan   11         2.0
# 2457      2019             Men    Lifestyle     Air Force 1    L        -1.0
# 2465      2019             Men   Basketball       LeBron 20  NaN         3.0
#
# ...

# %% [markdown]
# Pada tahap ini, kita akan mengecek duplikasi pada dataset. Hal ini dilakukan agar dataset memiliki insight dan hasil yang bersih.

# %% [markdown]
# Temuan:
#
# Tidak terlihat indikasi duplikasi pada Order_ID (2500 unique entries diasumsikan unik).
#
# Insight:
#
# Jika Order_ID benar-benar unik, maka tidak ada transaksi ganda.
# Namun tetap perlu pengecekan dengan fungsi .duplicated() untuk memastikan.
#
# Kesimpulan:
#
# Secara struktur, dataset tampak tidak memiliki duplikasi.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Gender_Category, Product_Line, Product_Name, Size, Units_Sold, MRP, Discount_Applied, Revenue, Order_Date, Sales_Channel, Region, Profit]
# Index: []

# %% [markdown]
# Terlihat pada dataset ini tidak ada duplikasi. Maka hal ini tidak perlu ditangani, namun jika ingin menangani anda dapat mengetikkan
#
# df = df.drop_duplicates()

# %% [markdown]
# ### **Outliers Values**

# %%
numeric_cols = df.select_dtypes(include=['int64','float64']).columns

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]

    print(f"{col} → {len(outliers)} outliers")
# Out:
# Order_ID → 0 outliers
# Units_Sold → 0 outliers
# MRP → 0 outliers
# Discount_Applied → 0 outliers
# Revenue → 166 outliers
# Profit → 0 outliers

# %%
for col in numeric_cols:
    plt.figure(figsize=(6,4))
    sns.boxplot(y=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %% [markdown]
# Pada tahap ini, kita akan melihat nilai ekstrem (outliers) pada kolom yang bertipe data kan numerik. Hal ini dilakukan agar mendapatkan insight yang akurat sehingga dapat memperkuat analisis dan model yang akan kita bangun nantinya.

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom             Persentase Outliers
# Order_ID                         0.00
# Units_Sold                       0.00
# MRP                              0.00
# Discount_Applied                 0.00
# Revenue                          6.64
# Profit                           0.00

# %% [markdown]
# Temuan:
# * Revenue max = 37169,35 (sangat tinggi dibanding mean 274,87)
# * Std Revenue (2023,77) jauh lebih besar dari mean
# * Profit max = 3999,21
# * Units_Sold max = 4 (relatif kecil)
#
# Insight:
#
# Revenue sangat right-skewed. Ada transaksi bernilai sangat besar yang menarik rata-rata naik drastis.
# Ini menunjukkan kemungkinan:
# * Transaksi korporat
# * Penjualan bundle besar
# * Atau anomali input
#
# Kesimpulan:
#
# Outlier pada Revenue dan Profit perlu dianalisis:
# * Jika valid → itu high-value customer (peluang bisnis besar)
# * Jika tidak valid → perlu dibersihkan agar model tidak bias

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=df['Revenue'])
plt.title('Boxplot of Revenue')
plt.ylabel('Revenue')
plt.show()

# %% [markdown]
# # **Eksplorasi Data (EDA)**

# %% [markdown]
# ## **Comparison/Perbandingan**

# %% [markdown]
# Aktivitas:
#
# Mengelompokkan data berdasarkan Region, lalu menjumlahkan total Revenue pada setiap wilayah.
#
# Tujuan:
#
# Mengetahui wilayah mana yang paling dominan dalam menghasilkan pendapatan.
#
# Visualisasi:
#
# Bar Chart (Diagram Batang)

# %%
variabel = df.groupby('Region')['Revenue'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=variabel.index, y=variabel.values, palette='viridis', hue=variabel.index, legend=False)
plt.title('Total Penjualan Berdasarkan Wilayah')
plt.xlabel('Region')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Visualisasi menunjukkan adanya wilayah dengan kontribusi penjualan jauh lebih tinggi dibanding wilayah lainnya.
#
# Pandangan:
# * Wilayah dengan revenue tertinggi merupakan pasar utama perusahaan.
# * Wilayah dengan kontribusi rendah bisa disebabkan oleh:
#   * Distribusi belum optimal
#   * Daya beli rendah
#   * Kurangnya promosi
#
# Interpretasi Bisnis:
# * Perusahaan dapat:
#   * Fokus mempertahankan market share di wilayah dominan
#   * Mengembangkan strategi ekspansi di wilayah dengan potensi pertumbuhan
#
# Jika distribusi wilayah tidak merata, berarti pasar belum sepenuhnya tergarap.
#
# ---

# %% [markdown]
# Aktivitas:
#
# Mengelompokkan data berdasarkan Product_Line, kemudian menghitung total Revenue pada masing-masing lini produk.
#
# Tujuan:
#
# Mengetahui lini produk mana yang memberikan kontribusi pendapatan terbesar terhadap total penjualan perusahaan.
#
# Visualisasi:
#
# Bar Chart (Diagram Batang)

# %%
variabel = df.groupby('Product_Line')['Revenue'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=variabel.index, y=variabel.values, palette='viridis', hue=variabel.index, legend=False)
plt.title('Total Penjualan Berdasarkan Tipe Produk')
plt.xlabel('Product_Line')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Penjualan Berdasarkan Product_Line
#
# Dari grafik terlihat bahwa terdapat satu lini produk yang kontribusi revenue-nya paling tinggi dibandingkan lini lainnya, sementara satu atau dua lini berada di posisi paling rendah.
#
# Pandangan:
# * Perusahaan memiliki produk unggulan (core product) yang menjadi tulang punggung pendapatan.
# * Ketergantungan pada satu lini produk berisiko jika permintaan pasar berubah.
# * Lini produk dengan kontribusi rendah bisa menjadi peluang untuk strategi promosi atau inovasi produk.
#
# Interpretasi Bisnis:
#
# * Jika selisih antar produk cukup jauh, berarti strategi pemasaran belum merata. Perusahaan perlu:
#   * Meningkatkan awareness untuk produk dengan kontribusi rendah
#   * Mengevaluasi harga atau positioning produk yang kurang laku
#
# ---

# %% [markdown]
# Aktivitas:
#
# Mengelompokkan data berdasarkan Sales_Channel, lalu menghitung total Revenue masing-masing channel.
#
# Tujuan:
#
# Mengetahui channel penjualan mana yang lebih dominan dalam menghasilkan pendapatan.
#
# Visualisasi:
#
# Bar Chart (Diagram Batang)

# %%
variabel = df.groupby('Sales_Channel')['Revenue'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=variabel.index, y=variabel.values, palette='viridis', hue=variabel.index, legend=False)
plt.title('Total Penjualan Berdasarkan Retail & Online')
plt.xlabel('Sales_Channel')
plt.ylabel('Revenue')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Grafik menunjukkan perbandingan antara Online dan Retail.
#
# Pandangan:
# * Jika Online lebih tinggi → transformasi digital berjalan efektif.
# * Jika Retail lebih tinggi → model bisnis tradisional masih kuat.
# * Jika perbedaannya tipis → perusahaan memiliki keseimbangan channel yang baik.
#
# Interpretasi Bisnis:
#
# * Perusahaan perlu mengevaluasi:
#   * Efektivitas strategi omnichannel
#   * Biaya operasional masing-masing channel
#   * Margin profit per channel
#
# Revenue tinggi belum tentu profit tinggi, jadi sebaiknya lanjut analisis ke Profit per channel.
#
# ---

# %% [markdown]
# ## **Distribution/Distribusi**

# %% [markdown]
# Aktivitas:
#
# Menganalisis distribusi nilai Revenue untuk transaksi yang benar-benar menghasilkan pendapatan (Revenue > 0) guna memahami pola penyebaran nilai penjualan.
#
# Tujuan:
# * Mengetahui pola umum nilai transaksi yang menghasilkan revenue.
# * Mengidentifikasi apakah distribusi simetris atau condong ke satu sisi.
# * Melihat keberadaan transaksi bernilai sangat besar (high-value sales).
# * Memahami karakteristik pendapatan perusahaan secara lebih realistis (tanpa bias nol).
#
# Visualisasi:
#
# Histogram

# %%
sns.histplot(df[df['Revenue'] > 0]['Revenue'], bins=30, kde=True)
plt.title('Distribusi Revenue (Tanpa Nol)')
plt.show()

# %% [markdown]
# Penjelasan & Pandangan
#
# Grafik menunjukkan distribusi Revenue yang condong ke kanan (right-skewed), di mana sebagian besar transaksi berada pada rentang nilai rendah hingga menengah, sementara terdapat beberapa transaksi dengan nilai sangat tinggi.
#
# Pandangan:
# * Jika sebagian besar transaksi berada di nilai rendah → perusahaan mengandalkan volume penjualan.
# * Jika terdapat ekor panjang ke kanan → ada transaksi bernilai besar yang signifikan.
# * Jika outlier sangat jauh → pendapatan tidak merata antar transaksi.
#
# Dari grafik terlihat:
# * Mayoritas transaksi berada di kisaran revenue kecil–menengah.
# * Ada beberapa transaksi dengan nilai sangat tinggi (di atas 20.000–30.000).
# * Distribusi tidak normal dan tidak simetris.
#
# Interpretasi Bisnis
# * Perusahaan kemungkinan memiliki model bisnis campuran: banyak transaksi kecil + sedikit transaksi besar.
# * Transaksi bernilai tinggi bisa menjadi sumber profit utama.
# * Risiko: jika transaksi besar tersebut tidak konsisten, pendapatan bisa fluktuatif.
# * Median lebih representatif dibanding mean untuk menggambarkan kondisi umum.
#
# ---

# %% [markdown]
# ## **Composition/Komposisi**

# %% [markdown]
# Aktivitas:
# Melihat proporsi atau persentase total Revenue berdasarkan Product_Line.
#
# Tujuan:
# Mengetahui lini produk mana yang paling mendominasi total pendapatan perusahaan.
#
# Visualisasi:
# Pie Chart (Grafik Lingkaran)

# %%
product_revenue = df.groupby('Product_Line')['Revenue'].sum()

plt.figure(figsize=(10, 8))
plt.pie(product_revenue, labels=product_revenue.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('viridis', len(product_revenue)))
plt.title('Proporsi Revenue Berdasarkan Lini Produk')
plt.ylabel('') # Hide the default y-label
plt.show()

# %% [markdown]
# Penjelasan & Pandangan
#
# Grafik pie menunjukkan distribusi revenue yang tidak merata di antara lini produk. 'Training' dan 'Basketball' menjadi penyumbang terbesar, sementara 'Running' memiliki kontribusi paling kecil.
#
# Pandangan:
# *   **Ketergantungan pada Produk Unggulan:** Perusahaan sangat bergantung pada lini produk 'Training' dan 'Basketball' untuk pendapatan utama. Ini bisa menjadi kekuatan tetapi juga risiko jika terjadi perubahan tren pasar.
# *   **Potensi Pertumbuhan:** Lini produk dengan kontribusi lebih rendah seperti 'Running' dan 'Soccer' mungkin memiliki potensi untuk ditingkatkan melalui strategi pemasaran atau pengembangan produk yang lebih agresif.
# *   **Efektivitas Strategi Pemasaran:** Perlu dievaluasi apakah strategi pemasaran untuk lini produk 'Running' sudah seefektif lini produk lainnya.
#
# Interpretasi Bisnis:
#
# *   **Fokus Strategis:** Nike dapat terus mengoptimalkan dan berinovasi pada produk 'Training' dan 'Basketball' untuk mempertahankan kepemimpinan pasar.
# *   **Diversifikasi Risiko:** Untuk mengurangi ketergantungan, perusahaan perlu mengidentifikasi peluang untuk meningkatkan penjualan di lini produk lain, mungkin dengan menargetkan segmen pelanggan baru atau meningkatkan fitur produk.
# *   **Alokasi Sumber Daya:** Alokasi anggaran pemasaran dan R&D mungkin perlu ditinjau ulang agar lebih merata atau difokuskan pada lini produk dengan potensi pertumbuhan tinggi.

# %% [markdown]
# ## **Relationship/Hubungan**

# %% [markdown]
# Aktivitas:
#
# Menganalisis hubungan antara 'Discount_Applied' dan 'Profit' untuk melihat dampak diskon terhadap keuntungan.

# %% [markdown]
# Tujuan:
#
# *   Memahami apakah ada korelasi positif atau negatif antara diskon dan profit.
# *   Mengidentifikasi ambang batas diskon yang optimal atau merugikan.
# *   Menilai efektivitas strategi diskon perusahaan.

# %% [markdown]
# Visualisasi: Heatmap

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['Discount_Applied', 'Profit']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Korelasi antara Discount_Applied dan Profit')
plt.show()

# %% [markdown]
# Penjelasan & Pandangan
#
# Berdasarkan perhitungan korelasi, nilai korelasi antara 'Discount_Applied' dan 'Profit' adalah -0.37 (atau sekitar -0.38 seperti yang terlihat di heatmap).
#
# Pandangan:
# *   **Korelasi Negatif Moderat:** Nilai korelasi sekitar -0.37 menunjukkan hubungan negatif yang moderat antara diskon yang diberikan dan keuntungan. Ini berarti bahwa, secara umum, ketika diskon yang diterapkan meningkat, keuntungan cenderung menurun.
# *   **Dampak Negatif Diskon:** Meskipun diskon sering digunakan untuk mendorong penjualan, korelasi negatif ini mengindikasikan bahwa diskon yang diberikan saat ini mungkin mengurangi margin keuntungan lebih dari yang diimbangi oleh peningkatan volume penjualan.
# *   **Bukan Hubungan Kuat:** Korelasi ini moderat, bukan sangat kuat (-1). Ini menunjukkan bahwa diskon adalah salah satu faktor yang mempengaruhi keuntungan, tetapi bukan satu-satunya. Ada faktor lain yang juga berperan, atau hubungan tersebut tidak sepenuhnya linear.
#
# Interpretasi Bisnis:
#
# *   **Evaluasi Strategi Diskon:** Nike perlu mengevaluasi kembali strategi diskonnya. Diskon mungkin menarik pelanggan dan meningkatkan revenue (pendapatan kotor), tetapi secara signifikan memakan profit (keuntungan bersih).
# *   **Optimalisasi Titik Diskon:** Perusahaan harus mencari 'titik manis' di mana diskon masih efektif menarik pelanggan tanpa terlalu banyak menggerus keuntungan. Ini mungkin melibatkan A/B testing berbagai tingkat diskon.
# *   **Fokus pada Nilai:** Selain diskon, Nike bisa mempertimbangkan untuk menekankan nilai produk, kualitas, atau fitur unik untuk menarik pelanggan, sehingga tidak terlalu bergantung pada harga rendah.
# *   **Segmentasi Pelanggan:** Mungkin ada segmen pelanggan yang sensitif terhadap harga dan merespons diskon, sementara ada segmen lain yang lebih menghargai brand atau kualitas. Strategi diskon bisa lebih ditargetkan.
#
# ---

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ###**Data Type Check**

# %%
df.dtypes
# Out:
# Order_ID              int64
# Gender_Category      object
# Product_Line         object
# Product_Name         object
# Size                 object
# Units_Sold          float64
# MRP                 float64
# Discount_Applied    float64
# Revenue             float64
# Order_Date           object
# Sales_Channel        object
# Region               object
# Profit              float64
# dtype: object

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], errors='coerce')

# %%
df['Revenue'] = df['Revenue'].replace('[\$,]', '', regex=True)
df['Revenue'] = pd.to_numeric(df['Revenue'], errors='coerce')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# /tmp/ipykernel_443/1707224390.py:1: SyntaxWarning: invalid escape sequence '\$'
#   df['Revenue'] = df['Revenue'].replace('[\$,]', '', regex=True)

# %%
df['Revenue'] = df['Units_Sold'] * df['MRP'] * (1 - df['Discount_Applied'])

# %% [markdown]
# ### **Inconsistent Values**

# %% [markdown]
# ####**Gender_Category**

# %%
print(df['Gender_Category'].unique())
# Out:
# ['Kids' 'Women' 'Men']

# %% [markdown]
# Pada kolom ini seluruhnya kosisten

# %% [markdown]
# ####**Size**

# %%
print(df['Size'].unique())
# Out:
# ['M' 'L' 'XL' '11' nan '9' '6' '12' '7' '10' '8']

# %% [markdown]
# Tidak konsisten karena terdapat 2 format yang ada dalam satu kolom.

# %%
df['Size'] = df['Size'].replace({
    'M': '7 ',
    'L': '9 ',
    'XL': '11 ',

})

for col in ['Size']:
    print(df[col].unique())
# Out:
# ['7 ' '9 ' '11 ' '11' nan '9' '6' '12' '7' '10' '8']

# %% [markdown]
# ####**Region**

# %%
print(df['Region'].unique())
# Out:
# ['bengaluru' 'Hyd' 'Mumbai' 'Pune' 'Delhi' 'Bangalore' 'Hyderabad'
#  'hyderbad' 'Kolkata']

# %%
df['Region'] = df['Region'].replace({
    'bengaluru': 'Bangalore',
    'Hyd': 'Hyderabad',
    'hyderbad': 'Hyderabad',

})

for col in ['Region']:
    print(df[col].unique())
# Out:
# ['Bangalore' 'Hyderabad' 'Mumbai' 'Pune' 'Delhi' 'Kolkata']

# %% [markdown]
# diterapkan pada kolom Region. Semua huruf dibuat konsisten dan variasi seperti Bengaluru atau Hyd disamakan menjadi satu bentuk yang benar yaitu Bangalore dan Hyderabad.

# %% [markdown]
# ####**Product_Name**

# %%
print(df['Product_Name'].unique())
# Out:
# ['SuperRep Go' 'Tiempo Legend' 'Premier III' 'Blazer Mid' 'React Infinity'
#  'Flex Trainer' 'Mercurial Superfly' 'Waffle One' 'Air Jordan' 'Metcon 7'
#  'Air Zoom' 'Free RN' 'Kyrie Flytrap' 'Zoom Freak' 'ZoomX Invincible'
#  'Phantom GT' 'Pegasus Turbo' 'Dunk Low' 'Air Force 1' 'LeBron 20']

# %% [markdown]
# Pada kolom ini seluruhnya kosisten

# %% [markdown]
# ####**Order_Date**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                   Null Ratio in %
# Order_ID                     0.00
# Gender_Category              0.00
# Product_Line                 0.00
# Product_Name                 0.00
# Size                        20.40
# Units_Sold                  49.40
# MRP                         50.16
# Discount_Applied            66.72
# Revenue                      0.00
# Order_Date                  24.64
# Sales_Channel                0.00
# Region                       0.00
# Profit                       0.00

# %%
df['Order_Date'].isnull().sum()
# Out:
# np.int64(616)

# %% [markdown]
# pada awal tidak konsisten karena terdapat beberapa format yang berbeda seperti YYYY-MM-DD dan format lainnnya seperti DD-MM-YYYY. setelah dilakukan penanganan pada kolom ini akhirnya telah konsisten

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], errors='coerce')

median_date = df['Order_Date'].median()

df['Order_Date'] = df['Order_Date'].fillna(median_date)

# %%
df['Order_Date'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ####**Sales_Channel**

# %%
print(df['Sales_Channel'].unique())
# Out:
# ['Online' 'Retail']

# %% [markdown]
# Pada kolom ini konsisten

# %% [markdown]
# ####**Product_Line**

# %%
print(df['Product_Line'].unique())
# Out:
# ['Training' 'Soccer' 'Lifestyle' 'Running' 'Basketball']

# %% [markdown]
# Pada kolom ini seluruhnya kosisten

# %% [markdown]
# ### **Missing Values**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                   Null Ratio in %
# Order_ID                     0.00
# Gender_Category              0.00
# Product_Line                 0.00
# Product_Name                 0.00
# Size                        20.40
# Units_Sold                  49.40
# MRP                         50.16
# Discount_Applied            66.72
# Revenue                      0.00
# Order_Date                   0.00
# Sales_Channel                0.00
# Region                       0.00
# Profit                       0.00

# %% [markdown]
# > Pada dataset ini ditemukan beberapa kolom yang memiliki data kosong, yaitu Units_Sold 49.40%, MRP  50.16%, Discount_Applied 66.72%, dan Order_Date 24.64%. Sementara kolom lainnya sudah lengkap dan tidak ada yang kosong.

# %%
df['MRP'] = df.groupby('Product_Name')['MRP'].transform(lambda x: x.fillna(x.median()))

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                   Null Ratio in %
# Order_ID                     0.00
# Gender_Category              0.00
# Product_Line                 0.00
# Product_Name                 0.00
# Size                        20.40
# Units_Sold                  49.40
# MRP                          0.00
# Discount_Applied            66.72
# Revenue                      0.00
# Order_Date                   0.00
# Sales_Channel                0.00
# Region                       0.00
# Profit                       0.00

# %% [markdown]
# Kolom Order_Date yang memiliki missing values 24.64% ditangani menggunakan mode, yaitu mengisi data kosong dengan tanggal yang paling sering muncul dalam dataset.

# %%
df['Order_Date'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Revenue'] = pd.to_numeric(df['Revenue'], errors='coerce')
df['Region'] = df['Region'].astype(str)

df = df.dropna(subset=['Revenue','Region'])

# %% [markdown]
# ### **Duplicated Values**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Gender_Category, Product_Line, Product_Name, Size, Units_Sold, MRP, Discount_Applied, Revenue, Order_Date, Sales_Channel, Region, Profit]
# Index: []

# %% [markdown]
# Pada saat ini tidak ditemukan adanya data duplikat.

# %% [markdown]
# ###**Outliers Values**

# %%
numeric_cols = df.select_dtypes(include=['int64','float64']).columns

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]

    print(f"{col} → {len(outliers)} outliers")
# Out:
# Order_ID → 0 outliers
# Units_Sold → 0 outliers
# MRP → 452 outliers
# Discount_Applied → 0 outliers
# Revenue → 166 outliers
# Profit → 0 outliers

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom             Persentase Outliers
# Order_ID                         0.00
# Units_Sold                       0.00
# MRP                             18.08
# Discount_Applied                 0.00
# Revenue                          6.64
# Profit                           0.00

# %%
numeric_cols = ['Units_Sold', 'MRP', 'Discount_Applied', 'Revenue', 'Profit']

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]

    print(f"{col}")
    print("Jumlah outlier:", len(outliers))
    print("Lower bound:", lower_bound)
    print("Upper bound:", upper_bound)
    print()
# Out:
# Units_Sold
# Jumlah outlier: 0
# Lower bound: -4.5
# Upper bound: 7.5
#
# MRP
# Jumlah outlier: 452
# Lower bound: 3346.95
# Upper bound: 8503.27
#
# Discount_Applied
# Jumlah outlier: 0
# Lower bound: -0.6437499999999998
# Upper bound: 1.9262499999999996
#
# Revenue
# Jumlah outlier: 166
# Lower bound: 0.0
# Upper bound: 0.0
#
# Profit
# Jumlah outlier: 0
# Lower bound: -3757.1362500000005
# Upper bound: 6511.31375

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom             Persentase Outliers
# Order_ID                         0.00
# Units_Sold                       0.00
# MRP                             18.08
# Discount_Applied                 0.00
# Revenue                          6.64
# Profit                           0.00

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.boxplot(data=df[numeric_cols])
plt.title("Outliers Detection")
plt.show()

# %%
columns_to_impute = ["MRP"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom             Persentase Outliers
# Order_ID                         0.00
# Units_Sold                       0.00
# MRP                              0.00
# Discount_Applied                 0.00
# Revenue                          6.64
# Profit                           0.00

# %%
columns_to_impute = ["Revenue"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom             Persentase Outliers
# Order_ID                          0.0
# Units_Sold                        0.0
# MRP                               0.0
# Discount_Applied                  0.0
# Revenue                           0.0
# Profit                            0.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.boxplot(data=df[numeric_cols])
plt.title("Outliers Detection")
plt.show()

# %% [markdown]
# Berdasarkan hasil pengecekan outliers, kolom Units_Sold memiliki outliers 16.68%, MRP 49.84%, dan Discount_Applied 12.56%. Kolom Revenue berhasil ditangani dari yang sebelumnya memiliki outliers menjadi 0%.

# %%
print(df['Region'].unique())
print(df['Revenue'].isna().sum())
print(df.groupby('Region')['Revenue'].sum())
# Out:
# ['Bangalore' 'Hyderabad' 'Mumbai' 'Pune' 'Delhi' 'Kolkata']
# 0
# Region
# Bangalore    0.0
# Delhi        0.0
# Hyderabad    0.0
# Kolkata      0.0
# Mumbai       0.0
# Pune         0.0
# Name: Revenue, dtype: float64

# %% [markdown]
# #**Construct Data**

# %% [markdown]
# Pada tahap construct data, tidak dilakukan penambahan kolom baru karena seluruh fitur yang dibutuhkan untuk analisis sudah tersedia dalam dataset.

# %% [markdown]
# #**Data Reduction**

# %% [markdown]
# tidak ada kolom yang dihapus karena dibutuhkan

# %% [markdown]
# # **Visualisasi**

# %% [markdown]
# ##**Bar Chart**

# %%
VARIABEL1 = df['Product_Line'].value_counts().head(5).sort_values(ascending=False)
VARIABEL2 = df[df['Product_Line'].isin(VARIABEL1.index)]

plt.figure(figsize=(10, 6))
sns.countplot(x='Product_Line', data=VARIABEL2, hue="Gender_Category", palette='pastel', order=VARIABEL1.index)
plt.title('Top 5 Product Line Terlaris')
plt.xlabel('Product Line')
plt.ylabel('Jumlah Transaksi')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Insight
#
# Grafik menunjukkan bahwa beberapa product line memiliki jumlah transaksi jauh lebih tinggi dibanding produk lain. Hal ini menandakan bahwa permintaan pasar lebih terfokus pada produk tertentu.
#
# Selain itu, terlihat juga perbedaan preferensi antara kategori gender, di mana beberapa produk lebih dominan dibeli oleh kategori tertentu.
#
# Action
#
# Perusahaan dapat:
#
# Memprioritaskan stok dan distribusi produk yang paling banyak terjual.
#
# Mengoptimalkan strategi promosi pada produk yang memiliki permintaan tinggi.
#
# Mengembangkan variasi produk baru dari product line yang paling populer untuk meningkatkan penjualan.

# %% [markdown]
# ##**Pie Chart**

# %%
# Mengisi variabel dan kolom
top_profit_region = df.groupby('Region')['Profit'].sum().sort_values(ascending=False)
top_3_regions = top_profit_region.head(3)

plt.figure(figsize=(10, 8))
top_3_regions.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)

# Mengisi Judul
plt.title('Top 3 Regions by Total Profit')
plt.ylabel('')

plt.axis('equal')
plt.show()

# %% [markdown]
# Insight
#
# Grafik menunjukkan bahwa beberapa region memberikan kontribusi revenue yang lebih besar dibandingkan region lainnya. Hal ini berarti terdapat wilayah yang menjadi pasar utama bagi perusahaan.
#
# Sebaliknya, terdapat juga region dengan kontribusi penjualan yang lebih kecil.
#
# Action
#
# Perusahaan dapat:
#
# Memperkuat strategi pemasaran di region dengan kontribusi revenue terbesar untuk mempertahankan performa penjualan.
#
# Mengembangkan strategi promosi khusus pada region dengan penjualan rendah agar potensi pasar dapat dimaksimalkan.

# %% [markdown]
# ##**Line Chart**

# %%
VARIABEL1 = df.groupby(df['Order_Date'].dt.to_period('M')).size()

plt.figure(figsize=(20, 6))
plt.plot(VARIABEL1.index.astype(str), VARIABEL1.values, marker='o', color='blue')
plt.title('Trend Jumlah Order per Bulan', fontsize=16)
plt.xlabel('Bulan', fontsize=12)
plt.ylabel('Jumlah Order', fontsize=12)
plt.grid(True)
plt.gcf().autofmt_xdate()
plt.tight_layout()
plt.show()

# %% [markdown]
# Insight
#
# Grafik tren menunjukkan bahwa jumlah transaksi penjualan mengalami fluktuasi setiap bulan. Pada beberapa periode terlihat peningkatan penjualan, sementara pada periode lain terjadi penurunan.
#
# Hal ini menunjukkan adanya pola musiman dalam penjualan produk.
#
# Action
#
# Perusahaan dapat:
#
# Menyiapkan stok produk lebih banyak pada periode dengan tren penjualan tinggi.
#
# Menjalankan program promosi atau diskon pada periode ketika penjualan menurun untuk menjaga stabilitas penjualan.

# %% [markdown]
# ##**Histogram**

# %%
plt.figure(figsize=(8,5))

plt.hist(df['Revenue'], bins=30, edgecolor='black')

plt.title('Distribusi Revenue')
plt.xlabel('Revenue')
plt.ylabel('Frekuensi')

plt.show()

# %% [markdown]
# Insight
#
# Histogram menunjukkan bahwa sebagian besar transaksi menghasilkan revenue dalam jumlah kecil hingga menengah, sementara hanya sedikit transaksi yang menghasilkan revenue sangat tinggi.
#
# Hal ini menunjukkan bahwa sebagian besar pelanggan melakukan pembelian dalam jumlah yang relatif kecil.
#
# Action
#
# Perusahaan dapat:
#
# Menggunakan strategi upselling atau bundling produk untuk meningkatkan nilai pembelian per transaksi.
#
# Menawarkan promo minimum pembelian untuk mendorong pelanggan membeli lebih banyak produk dalam satu transaksi.

# %% [markdown]
# ##**BoxPlot**

# %%
VARIABEL1 = df['Sales_Channel'].value_counts().head(5).index
VARIABEL2 = df[df['Sales_Channel'].isin(VARIABEL1)]

plt.figure(figsize=(12, 7))
sns.boxplot(x='Sales_Channel', y='Revenue', data=VARIABEL2, palette='viridis', order=VARIABEL1, hue='Sales_Channel', legend=False)
plt.title('Distribusi Revenue Berdasarkan Sales Channel', fontsize=16)
plt.xlabel('Sales Channel', fontsize=12)
plt.ylabel('Revenue', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# Insight
#
# Boxplot memperlihatkan perbandingan distribusi revenue antara penjualan melalui Online dan Retail. Dari grafik tersebut dapat terlihat channel mana yang memiliki median revenue lebih tinggi serta variasi penjualan yang lebih besar.
#
# Hal ini menunjukkan bahwa masing-masing channel memiliki performa yang berbeda dalam menghasilkan revenue.
#
# Action
#
# Perusahaan dapat:
#
# Mengoptimalkan channel penjualan dengan median revenue tertinggi.
#
# Mengembangkan strategi pemasaran digital untuk meningkatkan performa penjualan online jika potensinya besar.

# %% [markdown]
# ##**ScatterPlot**

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Revenue', y='Profit', hue='Sales_Channel', data=df)
plt.title('Hubungan Revenue dan Profit per Sales Channel')
plt.xlabel('Revenue')
plt.ylabel('Profit')
plt.legend(title='Sales Channel')
plt.show()

# %% [markdown]
# Insight
#
# Grafik scatter menunjukkan bahwa peningkatan revenue tidak selalu diikuti dengan peningkatan profit. Terdapat beberapa transaksi dengan revenue tinggi namun profit yang rendah atau bahkan negatif.
#
# Hal ini dapat disebabkan oleh pemberian diskon yang terlalu besar atau biaya operasional yang tinggi.
#
# Action
#
# Perusahaan dapat:
#
# Mengevaluasi strategi pemberian diskon agar tidak terlalu menekan profit.
#
# Fokus pada produk yang memiliki kombinasi revenue tinggi dan profit tinggi.

# %% [markdown]
# ##**Bubble Chart**

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='Revenue', y='Profit', size='Units_Sold', hue='Product_Line', data=df, sizes=(50, 1000), alpha=0.7, palette='viridis')
plt.title('Revenue vs Profit (Size: Units Sold, Color: Product Line)', fontsize=16)
plt.xlabel('Revenue', fontsize=12)
plt.ylabel('Profit', fontsize=12)
plt.grid(True)
plt.legend(title='Product Line', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# Insight
#
# Bubble chart menunjukkan hubungan antara revenue, profit, dan jumlah unit yang terjual. Ukuran bubble yang lebih besar menunjukkan produk dengan jumlah penjualan yang lebih tinggi.
#
# Dari grafik ini dapat terlihat bahwa beberapa produk memiliki volume penjualan tinggi namun profit yang tidak terlalu besar.
#
# Action
#
# Perusahaan dapat:
#
# Mengoptimalkan strategi harga untuk produk dengan volume penjualan tinggi agar margin keuntungan meningkat.
#
# Mengidentifikasi produk yang memiliki volume penjualan tinggi dan profit tinggi untuk dijadikan fokus utama dalam strategi penjualan.

# %% [markdown]
# ##**Heatmap**

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['Revenue', 'Profit', 'Units_Sold', 'Discount_Applied']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Heatmap Korelasi Variabel Numerik')
plt.show()

# %% [markdown]
# Insight
#
# Heatmap menunjukkan hubungan antara beberapa variabel numerik seperti Units Sold, MRP, Discount Applied, Revenue, dan Profit.
#
# Beberapa pola yang biasanya muncul adalah:
#
# Units Sold memiliki korelasi positif dengan Revenue
#
# Discount Applied memiliki korelasi negatif dengan Profit
#
# Hal ini menunjukkan bahwa semakin besar diskon yang diberikan, maka profit perusahaan cenderung menurun.
#
# Action
#
# Perusahaan dapat:
#
# Mengurangi diskon yang terlalu besar agar tidak mengurangi profit secara signifikan.
#
# Menggunakan strategi promosi alternatif seperti bundling produk atau promo terbatas dibandingkan diskon besar.

# %% [markdown]
# # **Menyimpan Dataset**

# %%
output_path = "/content/Nike_Sales_Uncleaned.csv"
df.to_csv(output_path, index=False)
print(f"File berhasil disimpan di {output_path}")
# Out:
# File berhasil disimpan di /content/Nike_Sales_Uncleaned.csv
